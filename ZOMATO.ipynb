# %% [markdown]
# # ZOMATO

# %%
import json
import requests

# %%
data={"user-key":"befd094f399ecac0623ed0f54c4dab43", "query":"Connaught Place"}
h={"accept":"application/json", "user_key":"14fff80fb67efe097bc7033153debb2e"}
response=requests.get("https://developers.zomato.com/api/v2.1/locations", params=data, headers=h)
location=response.json()
location
# Out:
# {'location_suggestions': [{'entity_type': 'subzone',
#    'entity_id': 104,
#    'title': 'Connaught Place, New Delhi',
#    'latitude': 28.632832,
#    'longitude': 77.219688,
#    'city_id': 1,
#    'city_name': 'Delhi NCR',
#    'country_id': 1,
#    'country_name': 'India'}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
data={"user_key":"befd094f399ecac0623ed0f54c4dab43", "entity_id":"104", "entity_type":"subzone",
     "count":10, "cuisines":"73", "sort":"rating", "order":"desc", "category":"6"}
response=requests.get("https://developers.zomato.com/api/v2.1/search", params=data, headers=h)
rest=response.json()
rest
# Out:
# {'results_found': 5,
#  'results_start': 0,
#  'results_shown': 5,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 18729557},
#     'apikey': '14fff80fb67efe097bc7033153debb2e',
#     'id': '18729557',
#     'name': 'Xero Degrees',
#     'url': 'https://www.zomato.com/ncr/xero-degrees-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'L-23/9, Middle Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6343423459',
#      'longitude': '77.2213641554',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Cafe, Fast Food, Beverages',
#     'timings': '12:30PM to 11PM (Mon-Sun)',
#     'average_cost_for_two': 750,
#     'price_range': 2,
# ...

# %%
l=[]
id=[]
for i in rest['restaurants']:
        l.append([i['restaurant']['name'], i['restaurant']['user_rating']["aggregate_rating"]])
        id.append(i['restaurant']['R']['res_id'])

count=0
for i in range(len(l)):
    l[i].append(id[count])
    count+=1
l
# Out:
# [['Xero Degrees', '4.4', 18729557],
#  ['The Art House Bar n Cafe', '4.2', 18863766],
#  ['Chaayos - Meri Wali Chai', '4.0', 18237315],
#  ['Cafe Delhi Heights', '4.0', 18579363],
#  ['Cafe Coffee Day - The Square', '3.8', 303034]]

# %%
data={"user-key":"befd094f399ecac0623ed0f54c4dab43", "res_id":"18241524"}
h={"accept":"application/json", "user_key":"14fff80fb67efe097bc7033153debb2e"}
response=requests.get("https://developers.zomato.com/api/v2.1/restaurant", params=data, headers=h)
location=response.json()
location
# Out:
# {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#   'res_id': 18241524},
#  'apikey': '14fff80fb67efe097bc7033153debb2e',
#  'id': '18241524',
#  'name': '736 A.D.',
#  'url': 'https://www.zomato.com/ncr/736-a-d-vijay-nagar-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#  'location': {'address': 'G-15/B, Vijay Nagar, New Delhi',
#   'locality': 'Vijay Nagar',
#   'city': 'New Delhi',
#   'city_id': 1,
#   'latitude': '28.6942619387',
#   'longitude': '77.2036920860',
#   'zipcode': '110009',
#   'country_id': 1,
#   'locality_verbose': 'Vijay Nagar, New Delhi'},
#  'switch_to_order_menu': 0,
#  'cuisines': 'North Indian, Continental, Italian, Chinese',
#  'timings': '11 AM to 1 AM',
#  'average_cost_for_two': 1400,
#  'price_range': 3,
#  'currency': 'Rs.',
#  'highlights': ['Dinner',
#   'Cash',
#   'Takeaway Available',
#   'Debit Card',
#   'Lunch',
#   'Delivery',
#   'Credit Card',
#   'Live Sports Screening',
#   'Fullbar',
# ...

# %%
print(location['user_rating']['aggregate_rating'])
print(location['average_cost_for_two'])
print(location['cuisines'])
print(location['location']['address'])
# Out:
# 4.2
# 1400
# North Indian, Continental, Italian, Chinese
# G-15/B, Vijay Nagar, New Delhi

# %%
data={"user_key":"befd094f399ecac0623ed0f54c4dab43",'res_id' : '18241524'}
h={"accept":"application/json", "user_key":"14fff80fb67efe097bc7033153debb2e"}
response=requests.get("https://developers.zomato.com/api/v2.1/reviews", params=data, headers=h)
location=response.json()

for i in location['user_reviews']:
    print(i['review']['user']['name'],i['review']['rating'],i['review']['review_text'])
# Out:
# Shivam Yadav 5 Extremely pocket friendly . Provides a place if you want to celebrate with your friends in gtb nagar . Serrves great food and highlight for the place  are its chilly potatoes
# Craving Delight 5 So,its hard to find out in vijay nagar where should we go for best ambience and food..as there are so many choices, So I am suggesting you this place called "736 AD",One can enjoy the music beats here along with some good choice of menu. I did recommend you to try out their chicken burger,momos and Tandoori chicken in starters. If you wanna go for main course,you can give a try to biryani and for drinks..Oreo shake is the best shake. The place has some good background to click pictures on roof,it was totally my type of place and I had a great experience here
# Jagrit Mehra 4
# ...

# %% [markdown]
# # Project Details

# %%
# For this project, we are using the Zomato API.
# Zomato APIs give you access to the freshest and most exhaustive information for over 1.5 million restaurants across 10,000 cities globally.
# Zomato API documentation link
# Our Motivation for using Zomato API
# By Collecting the data using Zomato API one can recommend restaurants on the basis of user’s affinity to specific cuisines, establishment types, locations, and price bands.
# We can find out whether restaurant support online reservation or not.
# We can find what is the most popular and/ or exclusive/new at a given location & time.

# %% [markdown]
# ## Zomato cuisine problem details

# %%
# Mexican cuisine began about 9,000 years ago, when agricultural communities such as the Maya formed, domesticating maize, creating the standard process of corn nixtamalization, and establishing their foodways.
# You are a huge fan of ‘Mexican’ cuisine. Now using the Zomato API you want to analyse the best restaurant serving the Mexican Cuisine, their locations, and cost for two, etc.
# There is a list of questions related to Mexican cuisines given in the next section.

# %% [markdown]
# ## Zomato Cuisine 1.1

# %%
# Fetch the cuisine_id of ‘Mexican’ cuisine using Zomato API.
# Print the cuisine_id.
# Output Format:
# cuisine_id

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests
h = {'user-key' : 'befd094f399ecac0623ed0f54c4dab43'}
p={'city_id':2}
r = requests.get('https://developers.zomato.com/api/v2.1/cuisines', headers = h,params=p)
p=r.json()
#print(p['cuisines'])
for i in p['cuisines']:
    if(i['cuisine']['cuisine_name'] == 'Mexican'):
        print(i['cuisine']['cuisine_id'])
        break
#city=p['location_suggestions']
#print(city)
#for ele in city:
#    city_id=ele['id']
#    break
# Out:
# 73

# %%
## Zomato Cuisine 1.3

# %%
# Fetch the entityid and entitytype of place Connaught Place.
# Print the entityid and entitytype,
# Output Format:
# entity_type entity_id

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests
h = {'user-key' : 'befd094f399ecac0623ed0f54c4dab43'}
p={'query':'Connaught'}
r = requests.get('https://developers.zomato.com/api/v2.1/locations', headers = h,params=p)
p=r.json()
print(p['location_suggestions'][0]['entity_type'],p['location_suggestions'][0]['entity_id'])
#for i in p['cuisines']:
 #   if(i['cuisine']['cuisine_name'] == 'Mexican'):
  #      print(i['cuisine']['cuisine_id'])
   #     break
#city=p['location_suggestions']
#print(city)
#for ele in city:
#    city_id=ele['id']
#    break
# Out:
# subzone 104

# %%
## Zomato Cuisine 1.4

# %%
# Fetch the top 10 best-rated restaurant serving ‘Mexican’ cuisine present in Connaught Place.
# Print the restaurant name, user rating and restaurant id.
# Output Format:
# name_1 rating_1 id_1
# name_2 rating_2 id_2
# name_3 rating_3 id_3
# . . .
# . . .

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests
h = {'user-key' : 'befd094f399ecac0623ed0f54c4dab43'}
p={'entity_id':104,'entity_type' : 'subzone','sort':'rating','cuisines':73,'count':10}
r=requests.get('https://developers.zomato.com/api/v2.1/search',
                      headers={"User-agent": "curl/7.43.0",'Accept': 'application/json','user-key':'e445df301f18a32f94123f58b6d754f2'},
                      params=p)
p=r.json()
for i in p['restaurants']:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'])
# Out:
# Farzi Cafe 4.5 18233593
# Ministry Of Beer 4.4 18418277
# Chili's Grill & Bar 4.4 18537536
# Warehouse Cafe 4.3 301605
# Xero Degrees 4.3 18729557
# Unplugged Courtyard 4.2 18216901
# Pebble Street 4.2 309859
# Chaayos - Meri Wali Chai 4.2 18237315
# The Beer Cafe - BIGGIE 4.2 307060
# Rodeo Cantina & Kitchen 4.1 18673403

# %%
## Zomato Cuisine 1.5

# %%
# Fetch the category id of category type ‘Cafes’ using Zomato API.
# Print the category_id.
# Output Format:
# category_id

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests
h = {'user-key' : 'befd094f399ecac0623ed0f54c4dab43'}
#p={'entity_id':104,'entity_type' : 'subzone','sort':'rating','cuisines':73,'count':10}
r=requests.get('https://developers.zomato.com/api/v2.1/categories',
                      headers={"User-agent": "curl/7.43.0",'Accept': 'application/json','user-key':'e445df301f18a32f94123f58b6d754f2'})
p=r.json()
for i in p['categories']:
    if(i['categories']['name'] == 'Cafes'):
        print(i['categories']['id'])
        break
# Out:
# 6

# %%
## Zomato Cuisine 1.6

# %%
# Fetch the best-rated restaurant for ‘Mexican’ cuisine with category type ‘ Cafes’ present in Connaught Place using Zomato API.
# Print the restaurant name, user rating and restaurant id.
# Output Format:
# name_1 rating_1 id_1
# name_2 rating_2 id_2
# name_3 rating_3 id_3
# . . .
# . . .

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests
data={"user_key":"befd094f399ecac0623ed0f54c4dab43", "entity_id":"104", "entity_type":"subzone",
     "count":10, "cuisines":"73", "sort":"rating", "order":"desc", "category":"6"}
h={"accept":"application/json", "user_key":"14fff80fb67efe097bc7033153debb2e"}
response=requests.get("https://developers.zomato.com/api/v2.1/search", params=data, headers=h)
rest=response.json()
l=[]
id=[]
for i in rest['restaurants']:
    print(i['restaurant']['name'], i['restaurant']['user_rating']["aggregate_rating"],i['restaurant']['R']['res_id'])
        #id.append(i['restaurant']['R']['res_id'])

#count=0
#for i in range(len(l)):
 #   l[i].append(id[count])
  #  count+=1
#l
# Out:
# Xero Degrees 4.3 18729557
# Chaayos - Meri Wali Chai 4.2 18237315
# The Art House Bar n Cafe 4.0 18863766
# Cafe Coffee Day - The Square 3.5 303034

# %%
## Zomato Cuisine 1.7

# %%
# Fetch the latest review of the best-rated restaurant for ‘Mexican’ cuisine with Category type ‘Cafes’ present in Connaught Place using Zomato API.
# Print the name of user ,user rating and review text.
# Note :
# Due to limitation of basic API plan it, can only fetch 5 latest review
# Output Format:
# name1 user_rating1 review_text1
# name2 user_rating2 review_text2
# name3 user_rating3 review_text3
# name4 user_rating4 review_text4
# name5 user_rating5 review_text5

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43

import requests
header={"Accept": "application/json","User-Key": "befd094f399ecac0623ed0f54c4dab43",'User-Agent':'curl/7.43.0'}
cp_entity_id=18729557
c_entity_type='subzone'
params={'res_id':cp_entity_id}
r=requests.get('https://developers.zomato.com/api/v2.1'+'/reviews',headers=header,params=params)
for i in r.json().get('user_reviews'):
    print(i.get('review').get('user').get('name'),i.get('review').get('rating'),i.get('review').get('review_text'))
# Out:
# Janvi Kamra 5
# Harpriya Singh 4 It's an amazing place to chill out with your friends. The sitting space is less. Orders may take a little time but the food is worth the wait. There food is amazingly good. It's worth the money.
# Megha 5 Superb place to hang out and chill with your friends.  Food is super delicious.  Peri peri fries are to die for ❤️
# Prakriti Guglani 3 It's a cute place, hidden between the lanes of Connaught Place. It's budget friendly. It's a small place so you need to wait there sometimes. Overall, nice and a decent place. Doesn't bore a hole in your pockets. The food is decent too. Try shakes and fries for sure. Would rate everything 3.75/5.
# Dr.Manisha Pandey 4 Take away this pasta and bubble gum shake , initially I was planned to sit and eat but small outlet with not good condition,but I like the staff behavior,and must say food was nice and yes and won't charge my service tax.

# %%
# Zomato restaurant Problem Detail

# %%
# Problem 2
# "Pa Pa Ya" is a modern Asian bistro & tapas bar from the House of Massive Restaurants and best described as a chic, modern and radical reinterpretation of Asian cuisine.
# You have heard from your friends that restaurant "Pa Pa Ya" in Delhi is quite good. So now you want to extract the information related to "Pa Pa Ya" using Zomato API.
# There is a list of questions related to the restaurant given in the next section.

# %%
## Zomato Restaurant 2.2

# %%
# Fetch the details of "Pa Pa Ya" restaurant using Zomato API.
# Print the user rating, the average cost for two, cuisines and address of "Pa Pa Ya" restaurant.
# Output Format:
# user_rating
# average_cost_for_two
# cuisines
# address

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests

data={"user-key":"befd094f399ecac0623ed0f54c4dab43", "res_id":"18241524"}
h={"accept":"application/json", "user_key":"14fff80fb67efe097bc7033153debb2e"}
response=requests.get("https://developers.zomato.com/api/v2.1/restaurant", params=data, headers=h)
location=response.json()
print(location['user_rating']['aggregate_rating'])
print(location['average_cost_for_two'])
print(location['cuisines'])
print(location['location']['address'])
# Out:
# 3.9
# 1400
# North Indian, Continental, Italian, Chinese
# G-15/B, Vijay Nagar, New Delhi

# %%
## Zomato Restaurant 2.3

# %%
# Find out whether online table reservation is supported in "Pa Pa Ya" restaurant or not using Zomato API.
# Print 'yes' if online table reservation is supported else 'no'
# Note :
# In Zomato response JSON. 1=Yes and 0 = No
# Output Format:
# yes/no

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests

data={"user-key":"befd094f399ecac0623ed0f54c4dab43", "res_id":"18241524"}
h={"accept":"application/json", "user_key":"14fff80fb67efe097bc7033153debb2e"}
response=requests.get("https://developers.zomato.com/api/v2.1/restaurant", params=data, headers=h)
location=response.json()
if(location['is_table_reservation_supported']):
    print('yes')
else:
    print('no')
# Out:
# no

# %%
## Zomato Restaurant 2.4

# %%
# Fetch the latest review of "Pa Pa Ya" restaurant using Zomato API.
# Print the name of the user, user rating and review text.
# Note :
# Due to the limitation of the basic API plan, it can only fetch 5 latest review
# Output Format:
# name1 user_rating1 review_text1
# name2 user_rating2 review_text2
# name3 user_rating3 review_text3
# name4 user_rating4 review_text4
# name5 user_rating5 review_text5

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests

data={"user_key":"befd094f399ecac0623ed0f54c4dab43",'res_id' : '18241524'}
h={"accept":"application/json", "user_key":"14fff80fb67efe097bc7033153debb2e"}
response=requests.get("https://developers.zomato.com/api/v2.1/reviews", params=data, headers=h)
location=response.json()

for i in location['user_reviews']:
    print(i['review']['user']['name'],i['review']['rating'],i['review']['review_text'])

#l=[]
#id=[]
#for i in rest['restaurants']:
 #   print(i['restaurant']['name'], i['restaurant']['user_rating']["aggregate_rating"],i['restaurant']['R']['res_id'])
# Out:
# Sarthak & Ishita 4 Good portions, Pocket friendly, Tasty food. Upper floor had loud music, however if you want a quiet dining experience you can easily sit on the lower floor. Great Place! A must visit with friends..
# Bhawna Singla 5 This cafe is located in GTB Nagar. This is a pocked friendly place as this is located in GTB Nagar. 736 AD is famous for their Hookah. This place is so pretty and perfect for large group parties. I have celebrated my best friend's birthday, we were 9. It was a great time.  Would highly recommend for a visit.
# Foodpuff Girl 5 Went for a friend's birthday party there....  Nice place.... 👌👌 amazing view from the top 👌
# Big.time.food 5 People call this a non-veg platter, but I call it heaven on plate.❤️❤️ Non-veg platter is also my all time favourite.😋😋 Do you love non-veg platter too?😍😍 Had this Amazing Non-veg Platter from @736adcafe . Good staf nd gr8 services
# ...

# %%
# Zomato Distance Problem

# %%
# Distance is also a very important factor while selecting a restaurant. Suppose you are at Coding Ninjas and you want to select the restaurant which is near to you using Zomato API.
# Note down the latitude and longitude of Coding Ninjas using Google Maps
# There is a list of questions related to restaurant near me given in the next section.

# %%
## Zomato distance 3.1

# %%
# Fetch the cuisine_id of of cuisine ‘BBQ’ using Zomato API.
# Print the cuisine_id
# Output Format:
# cuisine_id

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests
h = {'user-key' : 'befd094f399ecac0623ed0f54c4dab43'}
p={'city_id':2}
r = requests.get('https://developers.zomato.com/api/v2.1/cuisines', headers = h,params=p)
p=r.json()
#print(p['cuisines'])
for i in p['cuisines']:
    if(i['cuisine']['cuisine_name'] == 'BBQ'):
        print(i['cuisine']['cuisine_id'])
        break
#city=p['location_suggestions']
#print(city)
#for ele in city:
#    city_id=ele['id']
#    break
# Out:
# 193

# %%
## Zomato distance 3.2

# %%
# Fetch the list of the top 10 restaurants serving cuisine ‘BBQ’ which are nearest to Coding Ninjas.
# Print the restaurant name, user rating, restaurant id and locality in which restaurant is present.
# Output Format:
# name_1 rating_1 id_1 locality_1
# name_2 rating_2 id_2 locality_2
# name_3 rating_3 id_3 locality_3
# . . .
# . . .

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43
import json
import requests
h = {'user-key' : 'befd094f399ecac0623ed0f54c4dab43'}
p={'lat':28.6975,'lon':77.1406,'cuisines':193,'sort':'real_distance','order':'asc','count':10}
response=requests.get('https://developers.zomato.com/api/v2.1/search',headers=h,params=p)
r=response.json()
#print(r)
for i in r['restaurants']:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'],i['restaurant']['location']['locality'])
# Out:
# Themis Barbecue House 4.3 18204820 Netaji Subhash Place
# Barbeque Nation 4.6 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Moet's Barbeque 0 19238917 Alipur
# UBQ by Barbeque Nation 3.1 18889760 Rohini
# Kays Bar-Be-Que 3.9 3079 Ashok Vihar Phase 1
# Chicken Adda 0 19179179 Rohini
# 7teen BBQ Bistro Bnq 3.9 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar
# Hunger On Wheels 0 19054336 Vijay Nagar

# %%
## Zomato distance 3.3

# %%
# Fetch the latest review of the restaurant serving cuisine ‘BBQ’ which is most nearest to Coding ninjas?
# Print the name of user ,user rating and review text.
# Note :
# Due to limitation of basic API plan it, can only fetch 5 latest review
# Output Format:
# name1 user_rating1 review_text1
# name2 user_rating2 review_text2
# name3 user_rating3 review_text3
# name4 user_rating4 review_text4
# name5 user_rating5 review_text5

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43

import requests
header={"Accept": "application/json","User-Key": "befd094f399ecac0623ed0f54c4dab43",'User-Agent':'curl/7.43.0'}
cp_entity_id=18204820
c_entity_type='subzone'
params={'res_id':cp_entity_id}
r=requests.get('https://developers.zomato.com/api/v2.1'+'/reviews',headers=header,params=params)
for i in r.json().get('user_reviews'):
    print(i.get('review').get('user').get('name'),i.get('review').get('rating'),i.get('review').get('review_text'))
# Out:
# Babu Beg 5 Staff was polite (5*) speedy service (5*) food was delicious and had plenty options. The only difference I could notice that staff was either not well aware of the schemes offered by the Restaurant or were pretending as there didn't exist any scheme (which otherwise were appearing even on the pamphlet put on the table). Still would love to visit again soon.
# SDS 4
# Abhishek Sharma 5 Their buffet is definitely better than barbeque nation.
# Sakshi Sabnani 4 We organized a get together here..ambiance and drinks was good but the food was not upto the mark but if you are going for dine out the food is good..maybe they weren't able to cater the party well.
# ANNANT VASHIST 5 I celebrated my bday in Themis barbecue . I enjoyed a lot and the staff was really good nd the food is very delicious .

# %%
## Zomato distance 3.4

# %%
# Experiment with the radius parameter that is present in ‘GET/search’. Fetch the list of top 10 best-restaurant present in a radius of 4 km of coding ninjas.
# Print the restaurant name, user rating, restaurant id and locality in which restaurant is present.
# Output Format:
# name_1 rating_1 id_1 locality_1
# name_2 rating_2 id_2 locality_2
# name_3 rating_3 id_3 locality_3
# . . .
# . . .

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43

import json
import requests
h = {'user-key' : 'befd094f399ecac0623ed0f54c4dab43'}

p={'lat':28.6975,'lon':77.1406,'sort':'rating','order':'desc','count':10,'radius' : 4000}
response=requests.get('https://developers.zomato.com/api/v2.1/search',headers=h,params=p)
r=response.json()
#print(r)
for i in r['restaurants']:
    print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'],i['restaurant']['location']['locality'])
# Out:
# Indian Accent 4.9 2004 The Lodhi, Lodhi Road
# Pa Pa Ya 4.9 18429148 Select Citywalk Mall, Saket
# The Big Chill 4.9 1614 Khan Market
# Kuremal Mohan Lal Kulfi Wale 4.9 303642 Chawri Bazar
# Dum-Pukht - ITC Maurya 4.9 2744 ITC Maurya, Chanakyapuri
# The Big Chill 4.9 8244 Khan Market
# Wenger's 4.8 4249 Connaught Place
# Manhattan Bar & Brewery 4.8 303960 Global Foyer Mall, Golf Course Road
# Natural Ice Cream 4.8 310143 Connaught Place
# Downtown - Diners & Living Beer Cafe 4.8 4959 Sector 29

# %%
## Zomato distance 3.5

# %%
# Compare the location of the restaurant whether really they are in a distance of 4 km to Coding Ninjas. Find out whether these API radius feature is working or not.
# Print 'yes' if radius feature work else print 'no'.
# Note :
# Use google search to find whether restaurant lie in range of 4km or not.
# Output Format:
# yes/no

# %%
## Open and read data file as specified in the question
## Print the required output in given format
## API : befd094f399ecac0623ed0f54c4dab43

#import json
#import requests
#h = {'user-key' : 'befd094f399ecac0623ed0f54c4dab43'}

#p={'lat':28.6975,'lon':77.1406,'sort':'rating','order':'desc','count':10,'radius' : 4000}
#response=requests.get('https://developers.zomato.com/api/v2.1/search',headers=h,params=p)
#r=response.json()
#print(r)
#for i in r['restaurants']:
 #   print(i['restaurant']['name'],i['restaurant']['user_rating']['aggregate_rating'],i['restaurant']['id'],i['restaurant']['location']['locality'])

    
print('no')
# Out:
# no
